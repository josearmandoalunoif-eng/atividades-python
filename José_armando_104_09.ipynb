# %% [markdown]
# <a href="https://colab.research.google.com/github/josearmandoalunoif-eng/atividades-python/blob/main/Jos%C3%A9_armando_104_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Guardando e analisando notas

# %%
notas = []
for i in range(5):
    nota = float(input("Digite a nota: "))
    notas.append(nota)

soma = 0
for nota in notas:
    soma += nota

media = soma / len(notas)

acima_ou_igual = 0
for nota in notas:
    if nota >= media:
        acima_ou_igual += 1

print("Notas:", notas)
print("Média:", media)
print("Notas >= média:", acima_ou_igual)
# Out:
# Digite a nota: 6
# Digite a nota: 8
# Digite a nota: 5
# Digite a nota: 7
# Digite a nota: 4
# Notas: [6.0, 8.0, 5.0, 7.0, 4.0]
# Média: 6.0
# Notas >= média: 3

# %% [markdown]
# 2. Coordenada representada por tupla

# %%
x = int(input("x: "))
y = int(input("y: "))

ponto = (x, y)

if ponto[0] == 0 and ponto[1] == 0:
    local = "Origem"
elif ponto[0] == 0:
    local = "Eixo Y"
elif ponto[1] == 0:
    local = "Eixo X"
elif ponto[0] > 0 and ponto[1] > 0:
    local = "1º quadrante"
elif ponto[0] < 0 and ponto[1] > 0:
    local = "2º quadrante"
elif ponto[0] < 0 and ponto[1] < 0:
    local = "3º quadrante"
else:
    local = "4º quadrante"

print("Ponto:", ponto)
print("Local:", local)
# Out:
# x: 5
# y: 6
# Ponto: (5, 6)
# Local: 1º quadrante

# %% [markdown]
# 3. Cadastro simples de produto

# %%
produto = {}
produto["nome"] = input("Nome: ")
produto["preco"] = float(input("Preço: "))
produto["quantidade"] = int(input("Quantidade: "))
total = produto["preco"] * produto["quantidade"]
print("Produto:", produto)
print("Valor em estoque:", total)
produto = {}
produto["nome"] = input("Nome: ")
produto["preco"] = float(input("Preço: "))
produto["quantidade"] = int(input("Quantidade: "))
total = produto["preco"] * produto["quantidade"]
print("Produto:", produto)
print("Valor em estoque:", total)
# Out:
# Nome: Caderno
# Preço: 12.00
# Quantidade: 5
# Produto: {'nome': 'Caderno ', 'preco': 12.0, 'quantidade': 5}
# Valor em estoque: 60.0
# Nome: Lápis
# Preço: 1.25
# Quantidade: 50
# Produto: {'nome': 'Lápis ', 'preco': 1.25, 'quantidade': 50}
# Valor em estoque: 62.5

# %% [markdown]
# 4. Lista de números: pares e ímpares

# %%
numeros = []
pares = []
impares = []
for i in range(10):
    n = int(input(f"Digite o {i+1}º número: "))
    numeros.append(n)
for num in numeros:
    if num % 2 == 0:
        pares.append(num)
    else:
        impares.append(num)
print("\n Lista completa:", numeros)
print("Números pares:", pares)
print("Números ímpares:", impares)
# Out:
# Digite o 1º número: 6
# Digite o 2º número: 8
# Digite o 3º número: 5
# Digite o 4º número: 3
# Digite o 5º número: 5
# Digite o 6º número: 8
# Digite o 7º número: 2
# Digite o 8º número: 9
# Digite o 9º número: 7
# Digite o 10º número: 5
#
#  Lista completa: [6, 8, 5, 3, 5, 8, 2, 9, 7, 5]
# Números pares: [6, 8, 8, 2]
# Números ímpares: [5, 3, 5, 9, 7, 5]

# %% [markdown]
# 5. Maior e menor da lista

# %%
numeros = []
for i in range(8):
    num = int(input(f"Digite o {i+1}º número: "))
    numeros.append(num)

maior = numeros[0]
menor = numeros[0]
pos_maior = 0
pos_menor = 0

for i in range(1, 8):
    if numeros[i] > maior:
        maior = numeros[i]
        pos_maior = i
    if numeros[i] < menor:
        menor = numeros[i]
        pos_menor = i

print("\nLista:", numeros)
print(f"Maior valor: {maior} na posição {pos_maior}")
print(f"Menor valor: {menor} na posição {pos_menor}")
# Out:
# Digite o 1º número: 6
# Digite o 2º número: 8
# Digite o 3º número: 7
# Digite o 4º número: 7
# Digite o 5º número: 6
# Digite o 6º número: 5
# Digite o 7º número: 3
# Digite o 8º número: 2
#
# Lista: [6, 8, 7, 7, 6, 5, 3, 2]
# Maior valor: 8 na posição 1
# Menor valor: 2 na posição 7

# %% [markdown]
# 6. Nomes sem repetição

# %%
dias = ("Segunda", "Terca", "Quarta", "Quinta", "Sexta", "Sabado", "Domingo")
n = int(input("Numero 1 a 7: "))
if n >= 1 and n <= 7:
    print(dias[n-1])
else:
    print("Invalido")
# Out:
# Numero 1 a 7: 5
# Sexta

# %% [markdown]
# 7. Dias da semana em uma tupla

# %%
t = []
for i in range(6):
    t.append(int(input("Numero: ")))
t = tuple(t)

cont5 = 0
pos5 = -1
pares = 0

for i in range(6):
    if t[i] == 5:
        cont5 = cont5 + 1
        if pos5 == -1:
            pos5 = i
    if t[i] % 2 == 0:
        pares = pares + 1

print("5 apareceu", cont5)
print("Pos", pos5)
print("Pares", pares)
# Out:
# Numero: 6
# Numero: 7
# Numero: 3
# Numero: 9
# Numero: 3
# Numero: 8
# 5 apareceu 0
# Pos -1
# Pares 2

# %% [markdown]
# 8. Estatísticas de uma tupla

# %%
aluno = {}
aluno["nome"] = input("Nome: ")
aluno["turma"] = input("Turma: ")
aluno["nota1"] = float(input("Nota1: "))
aluno["nota2"] = float(input("Nota2: "))
aluno["media"] = (aluno["nota1"] + aluno["nota2"]) / 2

if aluno["media"] >= 7:
    aluno["situacao"] = "aprovado"
elif aluno["media"] >= 5:
    aluno["situacao"] = "recuperacao"
else:
    aluno["situacao"] = "reprovado"

print(aluno)
# Out:
# Nome: 6
# Turma: 1
# Nota1: 6
# Nota2: 7
# {'nome': '6', 'turma': '1', 'nota1': 6.0, 'nota2': 7.0, 'media': 6.5, 'situacao': 'recuperacao'}

# %% [markdown]
# 9. Dicionário de aluno

# %%
aluno = {}
aluno["nome"] = input("Nome: ")
aluno["turma"] = input("Turma: ")
aluno["nota1"] = float(input("Nota1: "))
aluno["nota2"] = float(input("Nota2: "))
aluno["media"] = (aluno["nota1"] + aluno["nota2"]) / 2

if aluno["media"] >= 7:
    aluno["situacao"] = "aprovado"
elif aluno["media"] >= 5:
    aluno["situacao"] = "recuperacao"
else:
    aluno["situacao"] = "reprovado"

print(aluno)
# Out:
# Nome: 6
# Turma: 6
# Nota1: 3
# Nota2: 9
# {'nome': '6', 'turma': '6', 'nota1': 3.0, 'nota2': 9.0, 'media': 6.0, 'situacao': 'recuperacao'}

# %% [markdown]
# 10. Consulta de preços

# %%
prod = {"arroz":6.5, "feijao":8, "macarrao":4.5, "carne":30, "leite":5}
nome = input("Produto: ")
if nome in prod:
    print(prod[nome])
else:
    print("Nao tem")
# Out:
# Produto: 8
# Nao tem

# %% [markdown]
# 11. Frequência das palavras

# %%
cont = {}
for i in range(8):
    p = input("Palavra: ")
    if p in cont:
        cont[p] = cont[p] + 1
    else:
        cont[p] = 1
print(cont)
# Out:
# Palavra: Gato
# Palavra: Cachorro
# Palavra: Pato
# Palavra: Rato
# Palavra: Pe
# Palavra: Cachorro
# Palavra: Pe
# Palavra: Rato
# {'Gato': 1, 'Cachorro ': 2, 'Pato ': 1, 'Rato': 2, 'Pe': 2}

# %% [markdown]
# 12. Estoque e atualização

# %%
est = {"arroz":10, "feijao":5, "acucar":8, "cafe":3}
nome = input("Produto: ")
qtd = int(input("Qtd: "))
if nome in est:
    if qtd <= est[nome]:
        est[nome] = est[nome] - qtd
        print("Ok")
    else:
        print("Sem estoque")
else:
    print("Nao existe")
print(est)
# Out:
# Produto: 7
# Qtd: 9
# Nao existe
# {'arroz': 10, 'feijao': 5, 'acucar': 8, 'cafe': 3}

# %% [markdown]
# 13. Cadastro de vários alunos

# %%
turma = []
for i in range(5):
    nome = input("Nome: ")
    n1 = float(input("N1: "))
    n2 = float(input("N2: "))
    turma.append({"nome":nome, "media":(n1+n2)/2})

for a in turma:
    print(a["nome"], a["media"])
# Out:
# Nome: Joao
# N1: 7
# N2: 8
# Nome: Pedro
# N1: 5
# N2: 7
# Nome: Jose
# N1: 10
# N2: 9
# Nome: Maria
# N1: 5
# N2: 9
# Nome: Karol
# N1: 6
# N2: 9
# Joao 7.5
# Pedro  6.0
# Jose 9.5
# Maria 7.0
# Karol 7.5

# %% [markdown]
# 14. Catálogo com código imutáve

# %%
lista = []
for i in range(5):
    cod = int(input("Cod: "))
    nome = input("Nome: ")
    preco = float(input("Preco: "))
    lista.append((cod, nome, preco))

busca = int(input("Buscar: "))
achei = False
for p in lista:
    if p[0] == busca:
        print(p[1], p[2])
        achei = True
if achei == False:
    print("Nao achou")
# Out:
# Cod: 8
# Nome: Jose
# Preco: 6
# Cod: 9
# Nome: Joao
# Preco: 6
# Cod: 7
# Nome: Jo
# Preco: 6
# Cod: 4
# Nome: Pedro
# Preco: 5
# Cod: 6
# Nome: Maria
# Preco: 7
# Buscar: 8
# Jose 6.0

# %% [markdown]
# 15. Mini sistema de estoque

# %%
estoque = []
for i in range(5):
    codigo = int(input("Codigo: "))
    nome = input("Nome: ")
    qtd = int(input("Qtd: "))
    preco = float(input("Preco: "))

    item = {"codigo": codigo, "nome": nome, "quantidade": qtd, "preco": preco}
    estoque.append(item)
for item in estoque:
    print(item)
total = 0
for item in estoque:
    total = total + item["quantidade"] * item["preco"]
print("Total:", total)
maior = estoque[0]
for item in estoque:
    if item["quantidade"] * item["preco"] > maior["quantidade"] * maior["preco"]:
        maior = item
print("Maior:", maior["nome"])
resumo = (5, total)
print(resumo)
# Out:
# Codigo: 8
# Nome: 9
# Qtd: 5
# Preco: 6
# Codigo: 6
# Nome: 4
# Qtd: 9
# Preco: 3
# Codigo: 9
# Nome: 7
# Qtd: 5
# Preco: 7
# Codigo: 9
# Nome: 3
# Qtd: 4
# Preco: 7
# Codigo: 6
# Nome: 8
# Qtd: 7
# Preco: 7
# {'codigo': 8, 'nome': '9', 'quantidade': 5, 'preco': 6.0}
# {'codigo': 6, 'nome': '4', 'quantidade': 9, 'preco': 3.0}
# {'codigo': 9, 'nome': '7', 'quantidade': 5, 'preco': 7.0}
# {'codigo': 9, 'nome': '3', 'quantidade': 4, 'preco': 7.0}
# {'codigo': 6, 'nome': '8', 'quantidade': 7, 'preco': 7.0}
# Total: 169.0
# Maior: 8
# (5, 169.0)
