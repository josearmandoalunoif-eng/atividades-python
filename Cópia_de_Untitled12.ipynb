# %% [markdown]
# <a href="https://colab.research.google.com/github/josearmandoalunoif-eng/atividades-python/blob/main/C%C3%B3pia_de_Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #4.impar e par

# %%
numero = int(input("Digite um número inteiro: "))
if numero % 2 == 0:
    print("Par")
else:
    print("Ímpar")
# Out:
# Digite um número inteiro: 6
# Par

# %% [markdown]
# #5.situacao do aluno

# %%
nota1 = float(input("Nota 1: "))
nota2 = float(input("Nota 2: "))
media = (nota1 + nota2) / 2

print(f"Média: {media:.1f}")
if media >= 7:
    print("Aprovado")
elif media >= 5:
    print("Recuperação")
else:
    print("Reprovado")
# Out:
# Nota 1: 7
# Nota 2: 8
# Média: 7.5
# Aprovado

# %% [markdown]
# #6.Maior entre três números

# %%
n1 = int(input("1º número: "))
n2 = int(input("2º número: "))
n3 = int(input("3º número: "))

maior = n1
if n2 > maior:
    maior = n2
if n3 > maior:
    maior = n3

print("Maior é:", maior)
# Out:
# 1º número: 3
# 2º número: 9
# 3º número: 10
# Maior é: 10

# %% [markdown]
# #7. Contagem crescente

# %%
n = int(input("Digite um número inteiro positivo N: "))
for i in range(1, n + 1):
    print(i, end=" ")
# Out:
# Digite um número inteiro positivo N: 9
# 1 2 3 4 5 6 7 8 9

# %% [markdown]
# #8. Somando de 1 até N

# %%
n = int(input("Digite N: "))
soma = 0

for i in range(1, n+1):
    soma = soma + i

print("Soma =", soma)
# Out:
# Digite N: 8
# Soma = 36

# %% [markdown]
# #9. Contando números pares

# %%
pares = 0

for i in range(10):
    num = int(input("Número: "))
    if num % 2 == 0:
        pares = pares + 1

print("Tem", pares, "pares")
# Out:
# Número: 8
# Número: 5
# Número: 6
# Número: 9
# Número: 2
# Número: 4
# Número: 22
# Número: 34
# Número: 66
# Número: 33
# Tem 7 pares

# %% [markdown]
# #10. Soma apenas dos positivos

# %%
X cásoma_pos = 0

for i in range(8):
    num = int(input("Número: "))
    if num > 0:
        soma_pos = soma_pos + num

print("Soma dos positivos =", soma_pos)
# Out:
# Número: 6
# Número: 8
# Número: 9
# Número: 4
# Número: 8
# Número: 9
# Número: 22
# Número: 34
# Soma dos positivos = 100

# %% [markdown]
# #11. Maior valor digitado

# %%
maior = int(input("Número: "))

for i in range(5):
    num = int(input("Número: "))
    if num > maior:
        maior = num

print("Maior é:", maior)
# Out:
# Número: 10
# Número: 18
# Número: 20
# Número: 6
# Número: 5
# Número: 4
# Maior é: 20

# %% [markdown]
# #12. Tabuada

# %%
num = int(input("Número: "))

for i in range(1, 11):
    print(num, "x", i, "=", num*i)
# Out:
# Número: 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# #13. Tentativas de senha

# %%
senha_certa = 1234
senha = int(input("Senha: "))

while senha != senha_certa:
    senha = int(input("Errada! Tente novamente: "))

print("Acesso permitido!")
# Out:
# Senha: 1822
# Errada! Tente novamente: 1234
# Acesso permitido!

# %% [markdown]
# #14. Número secreto

# %%
secreto = 7
tentativas = 0
palpite = 0

while palpite != secreto:
    palpite = int(input("Tente adivinhar: "))
    tentativas = tentativas + 1
    if palpite < secreto:
        print("É maior")
    elif palpite > secreto:
        print("É menor")

print("Acertou em", tentativas, "tentativas!")
# Out:
# Tente adivinhar: 8
# É menor
# Tente adivinhar: 10
# É menor
# Tente adivinhar: 7
# Acertou em 3 tentativas!

# %% [markdown]
# #15. Analisando uma sequência de números

# %%
quantidade = 0
positivos = 0
negativos = 0
soma = 0

while True:
    num = int(input("Número: "))
    if num == 0:
        break
    quantidade = quantidade + 1
    soma = soma + num
    if num > 0:
        positivos = positivos + 1
    else:
        negativos = negativos + 1

print("Quantidade =", quantidade)
print("Positivos =", positivos)
print("Negativos =", negativos)
print("Soma =", soma)
# Out:
# Número: 8
# Número: 6
# Número: 9
# Número: 5
# Número: 10
# Número: 11
# Número: 43
# Número: 99
# Número: 42
# Número: 23
# Número: -2
# Número: 0
# Quantidade = 11
# Positivos = 10
# Negativos = 1
# Soma = 254
